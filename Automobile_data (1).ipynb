# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv('/content/Automobile_data (3).csv')
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df["symboling"].value_counts()
# Out:
# symboling
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: count, dtype: int64

# %%
for columns in df.columns:
    print(df[columns].value_counts())
# Out:
# symboling
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: count, dtype: int64
# normalized-losses
# ?      41
# 161    11
# 91      8
# 150     7
# 128     6
# 104     6
# 134     6
# 74      5
# 103     5
# 168     5
# 95      5
# 102     5
# 94      5
# 65      5
# 85      5
# 93      4
# 106     4
# 118     4
# 122     4
# 148     4
# 154     3
# 83      3
# 125     3
# 115     3
# 137     3
# 101     3
# 194     2
# 197     2
# 188     2
# 164     2
# 158     2
# 192     2
# 110     2
# 145     2
# 113     2
# 81      2
# 89      2
# 87      2
# 108     2
# 119     2
# 153     2
# 129     2
# 98      1
# 121     1
# 107     1
# 78      1
# 231     1
# 142     1
# 77      1
# 186     1
# 90      1
# 256     1
# Name: count, dtype: int64
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# subaru           12
# volkswagen       12
# volvo            11
# peugot           11
# ...

# %%
df.replace("?",np.nan,inplace=True)

# %%
for columns in df.columns:
    print(df[columns].value_counts())
# Out:
# symboling
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: count, dtype: int64
# normalized-losses
# 161    11
# 91      8
# 150     7
# 128     6
# 104     6
# 134     6
# 74      5
# 103     5
# 168     5
# 95      5
# 102     5
# 94      5
# 65      5
# 85      5
# 93      4
# 106     4
# 118     4
# 122     4
# 148     4
# 154     3
# 83      3
# 125     3
# 115     3
# 137     3
# 101     3
# 194     2
# 197     2
# 188     2
# 164     2
# 158     2
# 192     2
# 110     2
# 145     2
# 113     2
# 81      2
# 89      2
# 87      2
# 108     2
# 119     2
# 153     2
# 129     2
# 98      1
# 121     1
# 107     1
# 78      1
# 231     1
# 142     1
# 77      1
# 186     1
# 90      1
# 256     1
# Name: count, dtype: int64
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# subaru           12
# volkswagen       12
# volvo            11
# peugot           11
# dodge             9
# ...

# %%
df.replace("peugot","peugeot",inplace=True)

# %%
df.replace("alfa-romero","alfa-romeo",inplace=True)

# %%
for columns in df.columns:
    print(df[columns].value_counts())
# Out:
# symboling
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: count, dtype: int64
# normalized-losses
# 161    11
# 91      8
# 150     7
# 128     6
# 104     6
# 134     6
# 74      5
# 103     5
# 168     5
# 95      5
# 102     5
# 94      5
# 65      5
# 85      5
# 93      4
# 106     4
# 118     4
# 122     4
# 148     4
# 154     3
# 83      3
# 125     3
# 115     3
# 137     3
# 101     3
# 194     2
# 197     2
# 188     2
# 164     2
# 158     2
# 192     2
# 110     2
# 145     2
# 113     2
# 81      2
# 89      2
# 87      2
# 108     2
# 119     2
# 153     2
# 129     2
# 98      1
# 121     1
# 107     1
# 78      1
# 231     1
# 142     1
# 77      1
# 186     1
# 90      1
# 256     1
# Name: count, dtype: int64
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# subaru           12
# volkswagen       12
# volvo            11
# peugeot          11
# dodge             9
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df.head()
# Out:
#    symboling normalized-losses        make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romeo       gas        std          two
# 1          3               NaN  alfa-romeo       gas        std          two
# 2          1               NaN  alfa-romeo       gas        std          two
# 3          2               164        audi       gas        std         four
# 4          2               164        audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df['normalized-losses'] = df['normalized-losses'].astype(float)
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df['bore'] = df['bore'].astype(float)
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df['stroke'] = df['stroke'].astype(float)
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df['horsepower'] = df['horsepower'].astype(float)
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df['peak-rpm'] = df['peak-rpm'].astype(float)
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df['price'] = df['price'].astype(float)
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
num_col=['normalized-losses','bore','stroke','horsepower','peak-rpm']
for i in num_col:
    df[i]=df[i].fillna(df[i].mean())

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df['num-of-doors']=df['num-of-doors'].fillna(df['num-of-doors'].mode()[0])

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df.dropna(subset=['price'],inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
pd.set_option('display.max_columns',None)
df
# Out:
#      symboling  normalized-losses        make fuel-type aspiration  \
# 0            3              122.0  alfa-romeo       gas        std
# 1            3              122.0  alfa-romeo       gas        std
# 2            1              122.0  alfa-romeo       gas        std
# 3            2              164.0        audi       gas        std
# 4            2              164.0        audi       gas        std
# ..         ...                ...         ...       ...        ...
# 196         -1               95.0       volvo       gas        std
# 197         -1               95.0       volvo       gas      turbo
# 198         -1               95.0       volvo       gas        std
# 199         -1               95.0       volvo    diesel      turbo
# 200         -1               95.0       volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df["normalized-losses"],bins=20,kde=True)
plt.title("distribution of normalized losses")
plt.show
print(df["normalized-losses"].describe())
# Out:
# count    201.00000
# mean     122.00000
# std       31.99625
# min       65.00000
# 25%      101.00000
# 50%      122.00000
# 75%      137.00000
# max      256.00000
# Name: normalized-losses, dtype: float64

# %%
sns.kdeplot(df["normalized-losses"],shade=True)
plt.title("KDE Plot of normalized-losses")
plt.show()
# Out:
# <ipython-input-36-6b623d6db61a>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["normalized-losses"],shade=True)

# %%
sns.histplot(df["wheel-base"],bins=20,kde=True)
plt.title("wheel base vs price")
plt.show
print(df["wheel-base"].describe())
# Out:
# count    201.000000
# mean      98.797015
# std        6.066366
# min       86.600000
# 25%       94.500000
# 50%       97.000000
# 75%      102.400000
# max      120.900000
# Name: wheel-base, dtype: float64

# %%
sns.histplot(df["length"],bins=20,kde=True)
plt.title("length vs price")
plt.show
print(df["length"].describe())
# Out:
# count    201.000000
# mean     174.200995
# std       12.322175
# min      141.100000
# 25%      166.800000
# 50%      173.200000
# 75%      183.500000
# max      208.100000
# Name: length, dtype: float64

# %%
sns.histplot(df["width"],bins=20,kde=True)
plt.title("width vs price")
plt.show
print(df["width"].describe())
# Out:
# count    201.000000
# mean      65.889055
# std        2.101471
# min       60.300000
# 25%       64.100000
# 50%       65.500000
# 75%       66.600000
# max       72.000000
# Name: width, dtype: float64

# %%
sns.histplot(df["height"],bins=20,kde=True)
plt.title("height vs price")
plt.show
print(df["height"].describe())
# Out:
# count    201.000000
# mean      53.766667
# std        2.447822
# min       47.800000
# 25%       52.000000
# 50%       54.100000
# 75%       55.500000
# max       59.800000
# Name: height, dtype: float64

# %%
sns.histplot(df["curb-weight"],bins=20,kde=True)
plt.title("curb-weight vs price")
plt.show
print(df["curb-weight"].describe())
# Out:
# count     201.000000
# mean     2555.666667
# std       517.296727
# min      1488.000000
# 25%      2169.000000
# 50%      2414.000000
# 75%      2926.000000
# max      4066.000000
# Name: curb-weight, dtype: float64

# %%
sns.histplot(df["engine-size"],bins=20,kde=True)
plt.title("engine-size vs price")
plt.show()
print(df["engine-size"].describe())
# Out:
# count    201.000000
# mean     126.875622
# std       41.546834
# min       61.000000
# 25%       98.000000
# 50%      120.000000
# 75%      141.000000
# max      326.000000
# Name: engine-size, dtype: float64

# %%
sns.histplot(df["bore"],bins=20,kde=True)
plt.title("bore vs price")
plt.show()
print(df["bore"].describe())
# Out:
# count    201.000000
# mean       3.330692
# std        0.268072
# min        2.540000
# 25%        3.150000
# 50%        3.310000
# 75%        3.580000
# max        3.940000
# Name: bore, dtype: float64

# %%
df.head()
# Out:
#    symboling  normalized-losses        make fuel-type aspiration num-of-doors  \
# 0          3              122.0  alfa-romeo       gas        std          two
# 1          3              122.0  alfa-romeo       gas        std          two
# 2          1              122.0  alfa-romeo       gas        std          two
# 3          2              164.0        audi       gas        std         four
# 4          2              164.0        audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
sns.histplot(df["stroke"],bins=20,kde=True)
plt.title("stroke vs price")
plt.show()
print(df["stroke"].describe())
# Out:
# count    201.000000
# mean       3.256874
# std        0.316048
# min        2.070000
# 25%        3.110000
# 50%        3.290000
# 75%        3.410000
# max        4.170000
# Name: stroke, dtype: float64

# %%
sns.histplot(df["compression-ratio"],bins=20,kde=True)
plt.title("compression-ratio vs price")
plt.show()
print(df["compression-ratio"].describe())
# Out:
# count    201.000000
# mean      10.164279
# std        4.004965
# min        7.000000
# 25%        8.600000
# 50%        9.000000
# 75%        9.400000
# max       23.000000
# Name: compression-ratio, dtype: float64

# %%
sns.histplot(df["horsepower"],bins=20,kde=True)
plt.title("horsepower vs price")
plt.show()
print(df["horsepower"].describe())
# Out:
# count    201.000000
# mean     103.405534
# std       37.365700
# min       48.000000
# 25%       70.000000
# 50%       95.000000
# 75%      116.000000
# max      262.000000
# Name: horsepower, dtype: float64

# %%
sns.histplot(df["peak-rpm"],bins=20,kde=True)
plt.title("peak-rpm vs price")
plt.show()
print(df["peak-rpm"].describe())
# Out:
# count     201.000000
# mean     5117.665368
# std       478.113805
# min      4150.000000
# 25%      4800.000000
# 50%      5125.369458
# 75%      5500.000000
# max      6600.000000
# Name: peak-rpm, dtype: float64

# %%
sns.histplot(df["city-mpg"],bins=20,kde=True)
plt.title("city-mpg vs price")
plt.show()
print(df["city-mpg"].describe())
# Out:
# count    201.000000
# mean      25.179104
# std        6.423220
# min       13.000000
# 25%       19.000000
# 50%       24.000000
# 75%       30.000000
# max       49.000000
# Name: city-mpg, dtype: float64

# %%
sns.histplot(df["highway-mpg"],bins=20,kde=True)
plt.title("highway-mpg vs price")
plt.show()
print(df["highway-mpg"].describe())
# Out:
# count    201.000000
# mean      30.686567
# std        6.815150
# min       16.000000
# 25%       25.000000
# 50%       30.000000
# 75%       34.000000
# max       54.000000
# Name: highway-mpg, dtype: float64

# %%
sns.histplot(df["price"],bins=20,kde=True)
plt.title("price vs price")
plt.show()
print(df["price"].describe())
# Out:
# count      201.000000
# mean     13207.129353
# std       7947.066342
# min       5118.000000
# 25%       7775.000000
# 50%      10295.000000
# 75%      16500.000000
# max      45400.000000
# Name: price, dtype: float64

# %% [markdown]
# UNIVARAITE CATAGORICAL

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df['make'])
plt.xticks(rotation=40)
plt.title("make count")
plt.show()

# %%
sns.countplot(x=df['fuel-type'])
plt.title("fuel-type count")
plt.show()
print(df["fuel-type"].describe())
# Out:
# count     201
# unique      2
# top       gas
# freq      181
# Name: fuel-type, dtype: object

# %%
sns.countplot(x=df['aspiration'])
plt.title("aspiration count")
plt.show()
print(df["aspiration"].describe())
# Out:
# count     201
# unique      2
# top       std
# freq      165
# Name: aspiration, dtype: object

# %%
sns.countplot(x=df['num-of-doors'])
plt.title("num-of-doors count")
plt.show()
print(df["num-of-doors"].describe())
# Out:
# count      201
# unique       2
# top       four
# freq       115
# Name: num-of-doors, dtype: object

# %%
sns.countplot(x=df['body-style'])
plt.title("body-style")
plt.show()
print(df["body-style"].describe())
# Out:
# count       201
# unique        5
# top       sedan
# freq         94
# Name: body-style, dtype: object

# %%
sns.countplot(x=df['drive-wheels'])
plt.title("drive-wheels")
plt.show()
print(df["drive-wheels"].describe())
# Out:
# count     201
# unique      3
# top       fwd
# freq      118
# Name: drive-wheels, dtype: object

# %%
sns.countplot(x=df['engine-location'])
plt.title("engine-location")
plt.show()
print(df["engine-location"].describe())
# Out:
# count       201
# unique        2
# top       front
# freq        198
# Name: engine-location, dtype: object

# %%
sns.countplot(x=df['engine-type'])
plt.title("engine-type")
plt.show()
print(df["engine-type"].describe())
# Out:
# count     201
# unique      6
# top       ohc
# freq      145
# Name: engine-type, dtype: object

# %%
sns.countplot(x=df['num-of-cylinders'])
plt.title("num-of-cylinders")
plt.show()
print(df["num-of-cylinders"].describe())
# Out:
# count      201
# unique       7
# top       four
# freq       157
# Name: num-of-cylinders, dtype: object

# %%
sns.countplot(x=df['fuel-system'])
plt.title("fuel-system")
plt.show()
print(df["fuel-system"].describe())
# Out:
# count      201
# unique       8
# top       mpfi
# freq        92
# Name: fuel-system, dtype: object

# %%
df
# Out:
#      symboling  normalized-losses        make fuel-type aspiration  \
# 0            3              122.0  alfa-romeo       gas        std
# 1            3              122.0  alfa-romeo       gas        std
# 2            1              122.0  alfa-romeo       gas        std
# 3            2              164.0        audi       gas        std
# 4            2              164.0        audi       gas        std
# ..         ...                ...         ...       ...        ...
# 196         -1               95.0       volvo       gas        std
# 197         -1               95.0       volvo       gas      turbo
# 198         -1               95.0       volvo       gas        std
# 199         -1               95.0       volvo    diesel      turbo
# 200         -1               95.0       volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['fuel-type']=lb.fit_transform(df['fuel-type'])
print(lb.classes_)
# Out:
# ['diesel' 'gas']

# %%
df
# Out:
#      symboling  normalized-losses        make  fuel-type aspiration  \
# 0            3              122.0  alfa-romeo          1        std
# 1            3              122.0  alfa-romeo          1        std
# 2            1              122.0  alfa-romeo          1        std
# 3            2              164.0        audi          1        std
# 4            2              164.0        audi          1        std
# ..         ...                ...         ...        ...        ...
# 196         -1               95.0       volvo          1        std
# 197         -1               95.0       volvo          1      turbo
# 198         -1               95.0       volvo          1        std
# 199         -1               95.0       volvo          0      turbo
# 200         -1               95.0       volvo          1      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
df['fuel-type'].unique()
# Out:
# array([1, 0])

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['aspiration']=lb.fit_transform(df['aspiration'])
print(lb.classes_)
# Out:
# ['std' 'turbo']

# %%
df['aspiration'].unique()
# Out:
# array([0, 1])

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['num-of-doors']=lb.fit_transform(df['num-of-doors'])
print(lb.classes_)
# Out:
# ['four' 'two']

# %%
df['num-of-doors'].unique()
# Out:
# array([1, 0])

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['body-style']=lb.fit_transform(df['body-style'])
print(lb.classes_)
# Out:
# ['convertible' 'hardtop' 'hatchback' 'sedan' 'wagon']

# %%
df['body-style'].unique()
# Out:
# array([0, 2, 3, 4, 1])

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['drive-wheels']=lb.fit_transform(df['drive-wheels'])
print(lb.classes_)
# Out:
# ['4wd' 'fwd' 'rwd']

# %%
df['drive-wheels'].unique()
# Out:
# array([2, 1, 0])

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['engine-location']=lb.fit_transform(df['engine-location'])
print(lb.classes_)
# Out:
# ['front' 'rear']

# %%
df['engine-location'].unique()
# Out:
# array([0, 1])

# %%
df['engine-type'].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'ohcf'], dtype=object)

# %%
df
# Out:
#      symboling  normalized-losses        make  fuel-type  aspiration  \
# 0            3              122.0  alfa-romeo          1           0
# 1            3              122.0  alfa-romeo          1           0
# 2            1              122.0  alfa-romeo          1           0
# 3            2              164.0        audi          1           0
# 4            2              164.0        audi          1           0
# ..         ...                ...         ...        ...         ...
# 196         -1               95.0       volvo          1           0
# 197         -1               95.0       volvo          1           1
# 198         -1               95.0       volvo          1           0
# 199         -1               95.0       volvo          0           1
# 200         -1               95.0       volvo          1           1
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  \
# ...

# %%
df['make'].unique()
# Out:
# array(['alfa-romeo', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'renault', 'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'],
#       dtype=object)

# %%
plt.figure(figsize=(20,5))
sns.barplot(x=df['make'],y=df['price'])
plt.xticks(rotation=45)
plt.title("make vs price")
plt.show()

# %%
# df['make']=df['make'].replace({'chevrolet':0,'dodge':0,'honda':0,'isuzu':0,'mazda':0,'mitsubishi':0,'nissan':0,'plymouth':0,'renault':0,'subaru':0,'toyota':0,'volkswagen':0})
# df['make']=df['make'].replace({'alfa-romeo':1,'audi':1,'mercury':1,'peugeot':1,'saab':1,'volvo':1})
# df['make']=df['make'].replace({'bmw':2,'jaguar':2,'mercedes-benz':2,'porsche':2})

# %%
df['make'].unique()
# Out:
# array(['alfa-romeo', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'renault', 'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'],
#       dtype=object)

# %%
df
# Out:
#      symboling  normalized-losses        make  fuel-type  aspiration  \
# 0            3              122.0  alfa-romeo          1           0
# 1            3              122.0  alfa-romeo          1           0
# 2            1              122.0  alfa-romeo          1           0
# 3            2              164.0        audi          1           0
# 4            2              164.0        audi          1           0
# ..         ...                ...         ...        ...         ...
# 196         -1               95.0       volvo          1           0
# 197         -1               95.0       volvo          1           1
# 198         -1               95.0       volvo          1           0
# 199         -1               95.0       volvo          0           1
# 200         -1               95.0       volvo          1           1
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  \
# ...

# %%
plt.figure(figsize=(20,5))
sns.barplot(x=df['num-of-cylinders'],y=df['price'])
plt.xticks(rotation=45)
plt.title("num-of-cylinders vs price")
plt.show()

# %%
# df['num-of-cylinders']=df['num-of-cylinders'].replace({'two':0,'four':0})
# df['num-of-cylinders']=df['num-of-cylinders'].replace({'one':1,'three':1})
# df['num-of-cylinders']=df['num-of-cylinders'].replace({'zero':2,'five':2,'six':2})

# %%
df
# Out:
#      symboling  normalized-losses        make  fuel-type  aspiration  \
# 0            3              122.0  alfa-romeo          1           0
# 1            3              122.0  alfa-romeo          1           0
# 2            1              122.0  alfa-romeo          1           0
# 3            2              164.0        audi          1           0
# 4            2              164.0        audi          1           0
# ..         ...                ...         ...        ...         ...
# 196         -1               95.0       volvo          1           0
# 197         -1               95.0       volvo          1           1
# 198         -1               95.0       volvo          1           0
# 199         -1               95.0       volvo          0           1
# 200         -1               95.0       volvo          1           1
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  \
# ...

# %%
plt.figure(figsize=(20,5))
sns.barplot(x=df['engine-type'],y=df['price'])
plt.xticks(rotation=45)
plt.title("engine-type vs price")
plt.show()

# %%
# compute mean target  for each category
target_mean = df.groupby('make')['price'].mean()

#replace category value with their target mean
df['make'] = df['make'].map(target_mean)

print(df)
# Out:
#      symboling  normalized-losses          make  fuel-type  aspiration  \
# 0            3              122.0  15498.333333          1           0
# 1            3              122.0  15498.333333          1           0
# 2            1              122.0  15498.333333          1           0
# 3            2              164.0  17859.166667          1           0
# 4            2              164.0  17859.166667          1           0
# ..         ...                ...           ...        ...         ...
# 196         -1               95.0  18063.181818          1           0
# 197         -1               95.0  18063.181818          1           1
# 198         -1               95.0  18063.181818          1           0
# 199         -1               95.0  18063.181818          0           1
# 200         -1               95.0  18063.181818          1           1
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  \
# ...

# %%
df
# Out:
#      symboling  normalized-losses          make  fuel-type  aspiration  \
# 0            3              122.0  15498.333333          1           0
# 1            3              122.0  15498.333333          1           0
# 2            1              122.0  15498.333333          1           0
# 3            2              164.0  17859.166667          1           0
# 4            2              164.0  17859.166667          1           0
# ..         ...                ...           ...        ...         ...
# 196         -1               95.0  18063.181818          1           0
# 197         -1               95.0  18063.181818          1           1
# 198         -1               95.0  18063.181818          1           0
# 199         -1               95.0  18063.181818          0           1
# 200         -1               95.0  18063.181818          1           1
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  \
# ...

# %%
# df['engine-type']=df['engine-type'].replace({'dohc':0,})
# df['engine-type']=df['engine-type'].replace({'one':1,'two':1,'three':1,'five':1})
# df['engine-type']=df['engine-type'].replace({'four':2})

# %%
target_mean = df.groupby('num-of-cylinders')['price'].mean()

#replace category value with their target mean
df['num-of-cylinders'] = df['num-of-cylinders'].map(target_mean)

print(df)
# Out:
#      symboling  normalized-losses          make  fuel-type  aspiration  \
# 0            3              122.0  15498.333333          1           0
# 1            3              122.0  15498.333333          1           0
# 2            1              122.0  15498.333333          1           0
# 3            2              164.0  17859.166667          1           0
# 4            2              164.0  17859.166667          1           0
# ..         ...                ...           ...        ...         ...
# 196         -1               95.0  18063.181818          1           0
# 197         -1               95.0  18063.181818          1           1
# 198         -1               95.0  18063.181818          1           0
# 199         -1               95.0  18063.181818          0           1
# 200         -1               95.0  18063.181818          1           1
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  \
# ...

# %%
df
# Out:
#      symboling  normalized-losses          make  fuel-type  aspiration  \
# 0            3              122.0  15498.333333          1           0
# 1            3              122.0  15498.333333          1           0
# 2            1              122.0  15498.333333          1           0
# 3            2              164.0  17859.166667          1           0
# 4            2              164.0  17859.166667          1           0
# ..         ...                ...           ...        ...         ...
# 196         -1               95.0  18063.181818          1           0
# 197         -1               95.0  18063.181818          1           1
# 198         -1               95.0  18063.181818          1           0
# 199         -1               95.0  18063.181818          0           1
# 200         -1               95.0  18063.181818          1           1
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  \
# ...

# %%
#  compute mean target  for each category
target_mean = df.groupby('engine-type')['price'].mean()

#replace category value with their target mean
df['engine-type'] = df['engine-type'].map(target_mean)

print(df)
# Out:
#      symboling  normalized-losses          make  fuel-type  aspiration  \
# 0            3              122.0  15498.333333          1           0
# 1            3              122.0  15498.333333          1           0
# 2            1              122.0  15498.333333          1           0
# 3            2              164.0  17859.166667          1           0
# 4            2              164.0  17859.166667          1           0
# ..         ...                ...           ...        ...         ...
# 196         -1               95.0  18063.181818          1           0
# 197         -1               95.0  18063.181818          1           1
# 198         -1               95.0  18063.181818          1           0
# 199         -1               95.0  18063.181818          0           1
# 200         -1               95.0  18063.181818          1           1
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  \
# ...

# %%
df
# Out:
#      symboling  normalized-losses          make  fuel-type  aspiration  \
# 0            3              122.0  15498.333333          1           0
# 1            3              122.0  15498.333333          1           0
# 2            1              122.0  15498.333333          1           0
# 3            2              164.0  17859.166667          1           0
# 4            2              164.0  17859.166667          1           0
# ..         ...                ...           ...        ...         ...
# 196         -1               95.0  18063.181818          1           0
# 197         -1               95.0  18063.181818          1           1
# 198         -1               95.0  18063.181818          1           0
# 199         -1               95.0  18063.181818          0           1
# 200         -1               95.0  18063.181818          1           1
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  \
# ...

# %%
#  compute mean target  for each category
target_mean = df.groupby('fuel-system')['price'].mean()

#replace category value with their target mean
df['fuel-system'] = df['fuel-system'].map(target_mean)

print(df)
# Out:
#      symboling  normalized-losses          make  fuel-type  aspiration  \
# 0            3              122.0  15498.333333          1           0
# 1            3              122.0  15498.333333          1           0
# 2            1              122.0  15498.333333          1           0
# 3            2              164.0  17859.166667          1           0
# 4            2              164.0  17859.166667          1           0
# ..         ...                ...           ...        ...         ...
# 196         -1               95.0  18063.181818          1           0
# 197         -1               95.0  18063.181818          1           1
# 198         -1               95.0  18063.181818          1           0
# 199         -1               95.0  18063.181818          0           1
# 200         -1               95.0  18063.181818          1           1
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  \
# ...

# %%
df
# Out:
#      symboling  normalized-losses          make  fuel-type  aspiration  \
# 0            3              122.0  15498.333333          1           0
# 1            3              122.0  15498.333333          1           0
# 2            1              122.0  15498.333333          1           0
# 3            2              164.0  17859.166667          1           0
# 4            2              164.0  17859.166667          1           0
# ..         ...                ...           ...        ...         ...
# 196         -1               95.0  18063.181818          1           0
# 197         -1               95.0  18063.181818          1           1
# 198         -1               95.0  18063.181818          1           0
# 199         -1               95.0  18063.181818          0           1
# 200         -1               95.0  18063.181818          1           1
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  \
# ...

# %% [markdown]
# OUTLIER CHECKING AND HANDLING

# %%
sns.boxplot(y=df['normalized-losses'])
plt.title('normalised losses')
plt.show()




    # Q1 = df[i].quantile(0.25)
    # Q3 = df[i].quantile(0.75)
    # IQR = Q3 - Q1

    # Define outlier thresholds
    # Minimum = Q1 - 1.5 * IQR
    # Maximum = Q3 + 1.5 * IQR

    # Apply outlier capping directly on 'normalized-losses'
    # df[i] = np.where(df[i] > Maximum, Maximum,
    # np.where(df[i] < Minimum, Minimum, df[i]))

# Print new shape after outlier capping
# print("New shape after outlier capping:", df.shape)

# %%
Q1 = df['normalized-losses'].quantile(0.25)
Q3 = df['normalized-losses'].quantile(0.75)
IQR = Q3 - Q1

Minimum = Q1 - 1.5 * IQR
Maximum = Q3 + 1.5 * IQR

df['normalized-losses'] = np.where(df['normalized-losses'] > Maximum, Maximum,
np.where(df['normalized-losses'] < Minimum, Minimum, df['normalized-losses']))

# %%
sns.boxplot(y=df['normalized-losses'])
plt.title('normalised losses')
plt.show()

# %%
sns.boxplot(y=df['wheel-base'])
plt.title('wheel-base')
plt.show()

# %%
Q1 = df['wheel-base'].quantile(0.25)
Q3 = df['wheel-base'].quantile(0.75)
IQR = Q3 - Q1

Minimum = Q1 - 1.5 * IQR
Maximum = Q3 + 1.5 * IQR

df['wheel-base'] = np.where(df['wheel-base'] > Maximum, Maximum,
np.where(df['wheel-base'] < Minimum, Minimum, df['wheel-base']))

# %%
sns.boxplot(y=df['wheel-base'])
plt.title('wheel-base')
plt.show()

# %%
sns.boxplot(y=df['length'])
plt.title('length')
plt.show()

# %%
sns.boxplot(y=df['width'])
plt.title('width')
plt.show()

# %%
Q1 = df['width'].quantile(0.25)
Q3 = df['width'].quantile(0.75)
IQR = Q3 - Q1

Minimum = Q1 - 1.5 * IQR
Maximum = Q3 + 1.5 * IQR

df['width'] = np.where(df['width'] > Maximum, Maximum,
np.where(df['width'] < Minimum, Minimum, df['width']))

# %%
sns.boxplot(y=df['width'])
plt.title('width')
plt.show()

# %%
sns.boxplot(y=df['height'])
plt.title('height')
plt.show()

# %%
sns.boxplot(y=df['curb-weight'])
plt.title('curb-weight')
plt.show()

# %%
Q1 = df['curb-weight'].quantile(0.25)
Q3 = df['curb-weight'].quantile(0.75)
IQR = Q3 - Q1

Minimum = Q1 - 1.5 * IQR
Maximum = Q3 + 1.5 * IQR

df['curb-weight'] = np.where(df['curb-weight'] > Maximum, Maximum,
np.where(df['curb-weight'] < Minimum, Minimum, df['curb-weight']))

# %%
sns.boxplot(y=df['curb-weight'])
plt.title('curb-weight')
plt.show()

# %%
sns.boxplot(y=df['engine-size'])
plt.title('engine-size')
plt.show()

# %%
Q1=df['engine-size'].quantile(0.25)
Q3=df['engine-size'].quantile(0.75)
IQR=Q3-Q1

Minimum=Q1-1.5*IQR
Maximum=Q3+1.5*IQR

df['engine-size']=np.where(df['engine-size']>Maximum,Maximum,np.where(df['engine-size']<Minimum,Minimum,df['engine-size']))

# %%
sns.boxplot(y=df['engine-size'])
plt.title('engine-size')
plt.show()

# %%
sns.boxplot(y=df['bore'])
plt.title('bore')
plt.show()

# %%
sns.boxplot(y=df['stroke'])
plt.title('stroke')
plt.show()

# %%
Q1=df['stroke'].quantile(0.25)
Q3=df['stroke'].quantile(0.75)
IQR=Q3-Q1

Minimum=Q1-1.5*IQR
Maximum=Q3+1.5*IQR

df['stroke']=np.where(df['stroke']>Maximum,Maximum,np.where(df['stroke']<Minimum,Minimum,df['stroke']))

# %%
sns.boxplot(y=df['stroke'])
plt.title('stroke')
plt.show()

# %%
sns.boxplot(y=df['compression-ratio'])
plt.title('compression-ratio')
plt.show()

# %%
Q1=df['compression-ratio'].quantile(0.25)
Q3=df['compression-ratio'].quantile(0.75)
IQR=Q3-Q1

Minimum=Q1-1.5*IQR
Maximum=Q3+1.5*IQR

df['compression-ratio']=np.where(df['compression-ratio']>Maximum,Maximum,np.where(df['compression-ratio']<Minimum,Minimum,df['compression-ratio']))

# %%
sns.boxplot(y=df['compression-ratio'])
plt.title('compression-ratio')
plt.show()

# %%
sns.boxplot(y=df['horsepower'])
plt.title('horsepower')
plt.show()

# %%
Q1=df['horsepower'].quantile(0.25)
Q3=df['horsepower'].quantile(0.75)
IQR=Q3-Q1

Minimum=Q1-1.5*IQR
Maximum=Q3+1.5*IQR

df['horsepower']=np.where(df['horsepower']>Maximum,Maximum,np.where(df['horsepower']<Minimum,Minimum,df['horsepower']))

# %%
sns.boxplot(y=df['horsepower'])
plt.title('horsepower')
plt.show()

# %%
sns.boxplot(y=df['peak-rpm'])
plt.title('peak-rpm')
plt.show()

# %%
Q1=df['peak-rpm'].quantile(0.25)
Q3=df['peak-rpm'].quantile(0.75)
IQR=Q3-Q1

Minimum=Q1-1.5*IQR
Maximum=Q3+1.5*IQR

df['peak-rpm']=np.where(df['peak-rpm']>Maximum,Maximum,np.where(df['peak-rpm']<Minimum,Minimum,df['peak-rpm']))

# %%
sns.boxplot(y=df['peak-rpm'])
plt.title('peak-rpm')
plt.show()

# %%
sns.boxplot(y=df['city-mpg'])
plt.title('city-mpg')
plt.show()

# %%
Q1=df['city-mpg'].quantile(0.25)
Q3=df['city-mpg'].quantile(0.75)
IQR=Q3-Q1

Minimum=Q1-1.5*IQR
Maximum=Q3+1.5*IQR

df['city-mpg']=np.where(df['city-mpg']>Maximum,Maximum,np.where(df['city-mpg']<Minimum,Minimum,df['city-mpg']))

# %%
sns.boxplot(y=df['city-mpg'])
plt.title('city-mpg')
plt.show()

# %%
sns.boxplot(y=df['highway-mpg'])
plt.title('highway-mpg')
plt.show()

# %%
Q1=df['highway-mpg'].quantile(0.25)
Q3=df['highway-mpg'].quantile(0.75)
IQR=Q3-Q1

Minimum=Q1-1.5*IQR
Maximum=Q3+1.5*IQR

df['highway-mpg']=np.where(df['highway-mpg']>Maximum,Maximum,np.where(df['highway-mpg']<Minimum,Minimum,df['highway-mpg']))

# %%
sns.boxplot(y=df['highway-mpg'])
plt.title('highway-mpg')
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.heatmap(df.corr(),annot=True,cmap="coolwarm",linewidths=0.5)
plt.title("correlation Heatmap")
plt.show()

# %%
df=df[["make","length","width","curb-weight","num-of-cylinders","engine-size","horsepower","city-mpg","highway-mpg","price"]]

# %%
df
# Out:
#              make  length  width  curb-weight  num-of-cylinders  engine-size  \
# 0    15498.333333   168.8   64.1       2548.0      10303.197452        130.0
# 1    15498.333333   168.8   64.1       2548.0      10303.197452        130.0
# 2    15498.333333   171.2   65.5       2823.0      23671.833333        152.0
# 3    17859.166667   176.6   66.2       2337.0      10303.197452        109.0
# 4    17859.166667   176.6   66.4       2824.0      22007.600000        136.0
# ..            ...     ...    ...          ...               ...          ...
# 196  18063.181818   188.8   68.9       2952.0      10303.197452        141.0
# 197  18063.181818   188.8   68.8       3049.0      10303.197452        141.0
# 198  18063.181818   188.8   68.9       3012.0      23671.833333        173.0
# 199  18063.181818   188.8   68.9       3217.0      23671.833333        145.0
# 200  18063.181818   188.8   68.9       3062.0      10303.197452        141.0
#
# ...

# %%
plt.figure(figsize=(20,5))
sns.heatmap(df.corr(),annot=True,cmap="coolwarm",linewidths=0.5)
plt.title("correlation Heatmap")
plt.show()

# %%
df=df[["make","width","curb-weight","engine-size","highway-mpg","horsepower","price"]]

# %%
df
# Out:
#              make  width  curb-weight  engine-size  highway-mpg  horsepower  \
# 0    15498.333333   64.1       2548.0        130.0         27.0       111.0
# 1    15498.333333   64.1       2548.0        130.0         27.0       111.0
# 2    15498.333333   65.5       2823.0        152.0         26.0       154.0
# 3    17859.166667   66.2       2337.0        109.0         30.0       102.0
# 4    17859.166667   66.4       2824.0        136.0         22.0       115.0
# ..            ...    ...          ...          ...          ...         ...
# 196  18063.181818   68.9       2952.0        141.0         28.0       114.0
# 197  18063.181818   68.8       3049.0        141.0         25.0       160.0
# 198  18063.181818   68.9       3012.0        173.0         23.0       134.0
# 199  18063.181818   68.9       3217.0        145.0         27.0       106.0
# 200  18063.181818   68.9       3062.0        141.0         25.0       114.0
#
#        price
# 0    13495.0
# 1    16500.0
# ...

# %% [markdown]
# # **SCALING**

# %% [markdown]
# # SPLITTING

# %%
x=df.drop(columns=['price'])
y=df['price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
x_train.shape
# Out:
# (160, 6)

# %%
x_test.shape
# Out:
# (41, 6)

# %%
df.shape
# Out:
# (201, 7)

# %%
y_train.shape
# Out:
# (160,)

# %%
y_test.shape
# Out:
# (41,)

# %% [markdown]
# SCALING

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_scaled=x_train.copy()
X_train_scaled=scaler.fit_transform(x_train)

X_test_scaled=x_test.copy()
X_test_scaled=scaler.transform(x_test)

print(X_test_scaled)
print(X_train_scaled)
# Out:
# [[-0.35240696 -1.03095348 -1.08400685 -0.8219881   0.98782512 -0.96680194]
#  [ 2.2409912   1.12528909  1.7144994   2.69922433 -1.35600116  2.42501669]
#  [-0.72085719 -0.97836219 -1.46951537 -0.98425595  1.1440802  -0.75668928]
#  [-0.43991352 -0.71540578 -0.81476281 -0.78953453  0.51905986 -0.93678585]
#  [ 0.44158959  0.38901114  0.24181608 -0.0431024  -0.41847065  0.26385792]
#  [-0.75739938 -1.03095348 -1.26758234 -1.04916309  1.61284546 -0.99681804]
#  [ 3.48429796  2.4137755   2.33661631  2.69922433 -1.9810215   1.61458215]
#  [-0.43991352  0.38901114 -0.25587745 -0.01064883  0.20654969 -0.27643178]
#  [-0.43991352  1.02010652  0.97203856  1.57957614 -1.04349099  1.79467872]
#  [ 3.64168797  2.01934088  3.10457375  2.69922433 -1.82476642  2.24492013]
#  [ 3.48429796  2.38747986  1.94906807  1.96901899 -0.88723591  0.65406714]
#  [-0.40825591 -0.13690168 -0.44965157 -0.8219881   1.76910054 -0.99681804]
# ...

# %% [markdown]
# MODEL **BUILDING**

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn=KNeighborsRegressor(n_neighbors=11)

# %%
knn.fit(X_train_scaled,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=11)

# %%
knn.score(X_train_scaled,y_train)
# Out:
# 0.862160037330219

# %%
knn.score(X_test_scaled,y_test)
# Out:
# 0.8572833887738116

# %%
 new_datapoint=np.array([[15498.333333,64.1,130.0	,2548.0,27.0,111.0]])

# %%
knn.predict(new_datapoint)
# Out:
# array([30191.63636364])

# %%
y_pred=knn.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([ 7006.27272727, 30051.18181818,  6459.54545455,  7567.90909091,
#        14395.45454545,  6191.90909091, 30490.27272727, 10122.09090909,
#        15822.72727273, 30051.18181818, 29462.27272727,  7794.45454545,
#        11364.63636364,  8966.63636364, 12349.54545455,  6506.45454545,
#        10249.63636364,  7252.63636364,  8966.63636364, 30490.27272727,
#        22164.        , 28884.90909091,  6923.63636364,  6947.54545455,
#        29462.27272727, 10129.63636364, 10156.81818182, 29462.27272727,
#        22164.        , 17017.09090909, 16215.        ,  6294.72727273,
#        10876.36363636,  6710.72727273,  7066.90909091, 17101.81818182,
#         7934.09090909,  8258.45454545, 11364.63636364,  9066.90909091,
#        14987.45454545])

# %%
y_test
# Out:
# 95      8249.0
# 15     41315.0
# 30      6855.0
# 158     9258.0
# 128    11850.0
# 115     5572.0
# 69     35056.0
# 171     9988.0
# 175    15998.0
# 45     35550.0
# 66     28176.0
# 183     9495.0
# 165     9989.0
# 78      8499.0
# 187    13295.0
# 178     7775.0
# 56      8845.0
# 152     6938.0
# 82      6989.0
# 68     34184.0
# 124    34028.0
# 16     36880.0
# 148     6488.0
# 93      7499.0
# 65     28248.0
# 60     10795.0
# 84      9279.0
# 67     31600.0
# 125    37028.0
# 132    18150.0
# 9      16430.0
# 18      6295.0
# 55     15645.0
# 75      6669.0
# 150     7898.0
# 104    11900.0
# 135     7053.0
# 137     7126.0
# 164     9639.0
# 76      7689.0
# 79     12629.0
# Name: price, dtype: float64

# %%
result=pd.DataFrame({"Actual":y_test,"Predicted":y_pred})

# %%
result
# Out:
#       Actual     Predicted
# 95    8249.0   7006.272727
# 15   41315.0  30051.181818
# 30    6855.0   6459.545455
# 158   9258.0   7567.909091
# 128  11850.0  14395.454545
# 115   5572.0   6191.909091
# 69   35056.0  30490.272727
# 171   9988.0  10122.090909
# 175  15998.0  15822.727273
# 45   35550.0  30051.181818
# 66   28176.0  29462.272727
# 183   9495.0   7794.454545
# 165   9989.0  11364.636364
# 78    8499.0   8966.636364
# 187  13295.0  12349.545455
# 178   7775.0   6506.454545
# 56    8845.0  10249.636364
# 152   6938.0   7252.636364
# 82    6989.0   8966.636364
# 68   34184.0  30490.272727
# 124  34028.0  22164.000000
# 16   36880.0  28884.909091
# 148   6488.0   6923.636364
# 93    7499.0   6947.545455
# 65   28248.0  29462.272727
# 60   10795.0  10129.636364
# 84    9279.0  10156.818182
# 67   31600.0  29462.272727
# 125  37028.0  22164.000000
# 132  18150.0  17017.090909
# 9    16430.0  16215.000000
# 18    6295.0   6294.727273
# 55   15645.0  10876.363636
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Actual and predicted values provided
actual_values = y_test
predicted_values = y_pred

# Calculate residuals (differences between actual and predicted values)
residuals = np.array(actual_values) - np.array(predicted_values)

# Create index values for the x-axis
x_values = np.arange(len(actual_values))

# Create a line plot for the predicted values
plt.plot(x_values, predicted_values, marker='o', linestyle='-', color='b', label='Predicted Values')

# Create a line plot for the actual values
plt.plot(x_values, actual_values, marker='x', linestyle='-', color='r', label='Actual Values')

# Add labels and title
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Actual vs Predicted Values')

# Add a legend to the plot
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# **VALIDATION** **FOR** **KNN**

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mse_knn=mean_squared_error(y_test,y_pred)
mae_knn=mean_absolute_error(y_test,y_pred)
r2_knn=r2_score(y_test,y_pred)

# %%
print("mean squared error",mse_knn)
print("mean absolute error",mae_knn)
print("r2 score",r2_knn)
# Out:
# mean squared error 17460916.848820798
# mean absolute error 2508.2549889135253
# r2 score 0.8572833887738116

# %% [markdown]
# **LINEAR** **REGRESSION**

# %%
from sklearn.linear_model import LinearRegression

# %%
Ln=LinearRegression()

# %%
Ln.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
Ln.score(X_train_scaled,y_train)
# Out:
# 0.8994119508519733

# %%
Ln.score(X_test_scaled,y_test)
# Out:
# 0.9165808690314644

# %%
y_pred_Ln=Ln.predict(X_test_scaled)

# %%
y_pred_Ln
# Out:
# array([ 7522.45870307, 28297.87497487,  6078.15207167,  7745.26167033,
#        14998.45695299,  5782.58295597, 32469.54474942, 10399.79666901,
#        16498.89656414, 34997.49288591, 30031.77360516,  8546.98403133,
#        12134.82420116,  9347.01503511, 12316.86508176,  7583.49890147,
#        10333.09455303,  7616.25954705,  9447.82097886, 32619.39142256,
#        29014.46862651, 29149.92563167,  6772.47306428,  7421.65275932,
#        30726.51727155,  9537.18757834, 10860.35919064, 30791.87741364,
#        29134.34596502, 18035.30654264, 19475.56379105,  4633.81595105,
#        12542.47062644,  6866.97232909,  7458.22145054, 15804.9834226 ,
#         7007.34693768,  8007.1609119 , 12093.95692666,  8914.31299971,
#        14288.95084122])

# %%
result_Ln=pd.DataFrame({"Actual":y_test,"Predicted":y_pred_Ln})

# %%
result_Ln
# Out:
#       Actual     Predicted
# 95    8249.0   7522.458703
# 15   41315.0  28297.874975
# 30    6855.0   6078.152072
# 158   9258.0   7745.261670
# 128  11850.0  14998.456953
# 115   5572.0   5782.582956
# 69   35056.0  32469.544749
# 171   9988.0  10399.796669
# 175  15998.0  16498.896564
# 45   35550.0  34997.492886
# 66   28176.0  30031.773605
# 183   9495.0   8546.984031
# 165   9989.0  12134.824201
# 78    8499.0   9347.015035
# 187  13295.0  12316.865082
# 178   7775.0   7583.498901
# 56    8845.0  10333.094553
# 152   6938.0   7616.259547
# 82    6989.0   9447.820979
# 68   34184.0  32619.391423
# 124  34028.0  29014.468627
# 16   36880.0  29149.925632
# 148   6488.0   6772.473064
# 93    7499.0   7421.652759
# 65   28248.0  30726.517272
# 60   10795.0   9537.187578
# 84    9279.0  10860.359191
# 67   31600.0  30791.877414
# 125  37028.0  29134.345965
# 132  18150.0  18035.306543
# 9    16430.0  19475.563791
# 18    6295.0   4633.815951
# 55   15645.0  12542.470626
# ...

# %%
mse_lnn=mean_squared_error(y_test,y_pred_Ln)
mae_lnn=mean_absolute_error(y_test,y_pred_Ln)
r2_lnn=r2_score(y_test,y_pred_Ln)

# %%
print("mean squared error",mse_lnn)
print("mean absolute error",mae_lnn)
print("r2 score",r2_lnn)
# Out:
# mean squared error 10206061.487362532
# mean absolute error 2011.2104350222503
# r2 score 0.9165808690314644

# %% [markdown]
# **DECISION** **TREE**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor

# %%
dt=DecisionTreeRegressor()

# %%
dt.fit(X_train_scaled,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt.score(X_train_scaled,y_train)
# Out:
# 0.9989831862870213

# %%
dt.score(X_test_scaled,y_test)
# Out:
# 0.9384833062125553

# %%
dt.predict(new_datapoint)
# Out:
# array([32528.])

# %%
dt.predict(X_test_scaled)
# Out:
# array([ 7349., 30760.,  6377.,  8358., 15250.,  6229., 36000., 10898.,
#        16558., 32250., 25552., 11395.,  8449.,  9960., 11199.,  7995.,
#        10595.,  7198.,  9960., 36000., 32528., 30760.,  6338.,  7299.,
#        25552., 11245.,  9279., 25552., 32528., 18620., 16925.,  5572.,
#        13645.,  6189.,  6918., 16630.,  6918.,  7775.,  8449.,  7957.,
#        11549.])

# %%
result_dt=pd.DataFrame({"Actual":y_test,"Predicted":y_pred})

# %%
result
# Out:
#       Actual     Predicted
# 95    8249.0   7006.272727
# 15   41315.0  30051.181818
# 30    6855.0   6459.545455
# 158   9258.0   7567.909091
# 128  11850.0  14395.454545
# 115   5572.0   6191.909091
# 69   35056.0  30490.272727
# 171   9988.0  10122.090909
# 175  15998.0  15822.727273
# 45   35550.0  30051.181818
# 66   28176.0  29462.272727
# 183   9495.0   7794.454545
# 165   9989.0  11364.636364
# 78    8499.0   8966.636364
# 187  13295.0  12349.545455
# 178   7775.0   6506.454545
# 56    8845.0  10249.636364
# 152   6938.0   7252.636364
# 82    6989.0   8966.636364
# 68   34184.0  30490.272727
# 124  34028.0  22164.000000
# 16   36880.0  28884.909091
# 148   6488.0   6923.636364
# 93    7499.0   6947.545455
# 65   28248.0  29462.272727
# 60   10795.0  10129.636364
# 84    9279.0  10156.818182
# 67   31600.0  29462.272727
# 125  37028.0  22164.000000
# 132  18150.0  17017.090909
# 9    16430.0  16215.000000
# 18    6295.0   6294.727273
# 55   15645.0  10876.363636
# ...

# %%
mse_decision_tree=mean_squared_error(y_test,y_pred)
mae_decision_tree=mean_absolute_error(y_test,y_pred)
r2_decision_tree=r2_score(y_test,y_pred)

# %%
print("mean squared error",mse_decision_tree)
print("mean absolute error",mae_decision_tree)
print("r2 score",r2_decision_tree)
# Out:
# mean squared error 17460916.848820798
# mean absolute error 2508.2549889135253
# r2 score 0.8572833887738116

# %%
import numpy as np
import matplotlib.pyplot as plt

# Actual and predicted values provided
actual_values = y_test
predicted_values = y_pred_Ln

# Calculate residuals (differences between actual and predicted values)
residuals = np.array(actual_values) - np.array(predicted_values)

# Create index values for the x-axis
x_values = np.arange(len(actual_values))

# Create a line plot for the predicted values
plt.plot(x_values, predicted_values, marker='o', linestyle='-', color='b', label='Predicted Values')

# Create a line plot for the actual values
plt.plot(x_values, actual_values, marker='x', linestyle='-', color='r', label='Actual Values')

# Add labels and title
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Actual vs Predicted Values')

# Add a legend to the plot
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# **RANDOM** **FOREST** **REGRESSOR**

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor()

# %%
rf=RandomForestRegressor()

# %%
rf.fit(X_train_scaled,y_train)
# Out:
# RandomForestRegressor()

# %%
rf.score(X_train_scaled,y_train)
# Out:
# 0.988672569169194

# %%
rf.score(X_test_scaled,y_test)
# Out:
# 0.9536173484812709

# %%
rf.predict(new_datapoint)
# Out:
# array([34442.34])

# %%
y_pred_rf=rf.predict(X_test_scaled)

# %%
result_rf=pd.DataFrame({"Actual":y_test,"Predicted":y_pred})

# %%
result_rf
# Out:
#       Actual     Predicted
# 95    8249.0   7006.272727
# 15   41315.0  30051.181818
# 30    6855.0   6459.545455
# 158   9258.0   7567.909091
# 128  11850.0  14395.454545
# 115   5572.0   6191.909091
# 69   35056.0  30490.272727
# 171   9988.0  10122.090909
# 175  15998.0  15822.727273
# 45   35550.0  30051.181818
# 66   28176.0  29462.272727
# 183   9495.0   7794.454545
# 165   9989.0  11364.636364
# 78    8499.0   8966.636364
# 187  13295.0  12349.545455
# 178   7775.0   6506.454545
# 56    8845.0  10249.636364
# 152   6938.0   7252.636364
# 82    6989.0   8966.636364
# 68   34184.0  30490.272727
# 124  34028.0  22164.000000
# 16   36880.0  28884.909091
# 148   6488.0   6923.636364
# 93    7499.0   6947.545455
# 65   28248.0  29462.272727
# 60   10795.0  10129.636364
# 84    9279.0  10156.818182
# 67   31600.0  29462.272727
# 125  37028.0  22164.000000
# 132  18150.0  17017.090909
# 9    16430.0  16215.000000
# 18    6295.0   6294.727273
# 55   15645.0  10876.363636
# ...

# %% [markdown]
#   **VALIDATION** **FOR** **RANDOM** **FOREST**

# %%
mse_random_forest=mean_squared_error(y_test,y_pred_rf)
mae_random_forest=mean_absolute_error(y_test,y_pred_rf)
r2_random_forest=r2_score(y_test,y_pred_rf)

# %%
print("mean squared error",mse_random_forest)
print("mean absolute error",mae_random_forest)
print("r2 score",r2_random_forest)
# Out:
# mean squared error 5674767.7403353825
# mean absolute error 1447.189451219512
# r2 score 0.9536173484812709

# %%
import numpy as np
import matplotlib.pyplot as plt

# Actual and predicted values provided
actual_values = y_test
predicted_values = y_pred_rf

# Calculate residuals (differences between actual and predicted values)
residuals = np.array(actual_values) - np.array(predicted_values)

# Create index values for the x-axis
x_values = np.arange(len(actual_values))

# Create a line plot for the predicted values
plt.plot(x_values, predicted_values, marker='o', linestyle='-', color='b', label='Predicted Values')

# Create a line plot for the actual values
plt.plot(x_values, actual_values, marker='x', linestyle='-', color='r', label='Actual Values')

# Add labels and title
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Actual vs Predicted Values')

# Add a legend to the plot
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# **BERNOULLI** (trail)

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
br=BernoulliNB()

# %%
br.fit(X_train_scaled,y_train)
# Out:
# BernoulliNB()

# %%
br.score(X_train_scaled,y_train)
# Out:
# 0.125

# %%
br.score(X_test_scaled,y_test)
# Out:
# 0.0

# %%
br.predict(new_datapoint)
# Out:
# array([9295.])

# %%
y_pred=rf.predict(X_test_scaled)

# %%
result_br=pd.DataFrame({"Actual":y_test,"Predicted":y_pred})

# %%
result_br
# Out:
#       Actual     Predicted
# 95    8249.0   7353.050000
# 15   41315.0  31110.710000
# 30    6855.0   6154.460000
# 158   9258.0   8153.770000
# 128  11850.0  13638.310000
# 115   5572.0   5964.620000
# 69   35056.0  35369.350000
# 171   9988.0  10465.731667
# 175  15998.0  16785.760000
# 45   35550.0  33514.810000
# 66   28176.0  25580.870000
# 183   9495.0   8558.880000
# 165   9989.0  10413.943333
# 78    8499.0   8838.630000
# 187  13295.0  13423.445000
# 178   7775.0   7762.800000
# 56    8845.0  10282.256667
# 152   6938.0   7636.940000
# 82    6989.0   9054.240000
# 68   34184.0  35568.020000
# 124  34028.0  31159.750000
# 16   36880.0  33159.150000
# 148   6488.0   6446.081667
# 93    7499.0   7058.355000
# 65   28248.0  26741.020000
# 60   10795.0  10123.680000
# 84    9279.0   9583.743333
# 67   31600.0  27396.540000
# 125  37028.0  31054.650000
# 132  18150.0  17707.570000
# 9    16430.0  15869.810000
# 18    6295.0   5964.950000
# 55   15645.0  13222.476667
# ...

# %% [markdown]
# **GAUSSIAN** **REGRESSOR**

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gu=GaussianNB()

# %%
gu.fit(X_train_scaled,y_train)
# Out:
# GaussianNB()

# %%
gu.score(X_train_scaled,y_train)
# Out:
# 0.96875

# %%
gu.score(X_test_scaled,y_test)
# Out:
# 0.024390243902439025

# %%
gu.predict(new_datapoint)
# Out:
# array([8495.])

# %%
gu_pred=gu.predict(X_test_scaled)

# %%
gu_result=pd.DataFrame({'Actual':y_test,'Predicted':gu_pred})

# %%
gu_result
# Out:
#       Actual  Predicted
# 95    8249.0     8495.0
# 15   41315.0     8495.0
# 30    6855.0     8495.0
# 158   9258.0     8495.0
# 128  11850.0     8495.0
# 115   5572.0     8495.0
# 69   35056.0     8495.0
# 171   9988.0    10898.0
# 175  15998.0     8495.0
# 45   35550.0    32250.0
# 66   28176.0     8495.0
# 183   9495.0     8495.0
# 165   9989.0     8495.0
# 78    8499.0     8495.0
# 187  13295.0     8495.0
# 178   7775.0     8495.0
# 56    8845.0    10595.0
# 152   6938.0     8495.0
# 82    6989.0     8495.0
# 68   34184.0     8495.0
# 124  34028.0    32528.0
# 16   36880.0     8495.0
# 148   6488.0     8495.0
# 93    7499.0     8495.0
# 65   28248.0     8495.0
# 60   10795.0     8495.0
# 84    9279.0     9279.0
# 67   31600.0     8495.0
# 125  37028.0     8495.0
# 132  18150.0     8495.0
# 9    16430.0    16925.0
# 18    6295.0     8495.0
# 55   15645.0     8495.0
# 75    6669.0     8495.0
# 150   7898.0     8495.0
# 104  11900.0     8495.0
# 135   7053.0     8495.0
# ...

# %% [markdown]
# **VALIDATION** **FOR** ***GUASSIAN***

# %%
mse=mean_squared_error(y_test,gu_pred)
mae=mean_absolute_error(y_test,gu_pred)
r2=r2_score(y_test,gu_pred)

# %%
print("mean squared error",mse)
print("mean absolute error",mae)
print("r2 score",r2)
# Out:
# mean squared error 139017846.68292683
# mean absolute error 6805.463414634146
# r2 score -0.1362608361478459

# %%
import numpy as np
import matplotlib.pyplot as plt

# Actual and predicted values provided
actual_values = y_test
predicted_values = y_pred_rf

# Calculate residuals (differences between actual and predicted values)
residuals = np.array(actual_values) - np.array(predicted_values)

# Create index values for the x-axis
x_values = np.arange(len(actual_values))

# Create a line plot for the predicted values
plt.plot(x_values, predicted_values, marker='o', linestyle='-', color='b', label='Predicted Values')

# Create a line plot for the actual values
plt.plot(x_values, actual_values, marker='x', linestyle='-', color='r', label='Actual Values')

# Add labels and title
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Actual vs Predicted Values')

# Add a legend to the plot
plt.legend()

# Show the plot
plt.show()
